# %%
from causal_nh.utils import open_pkl_file
from causal_nh.test import test_prediction
from causal_nh.train import train_nh, train_causal_nh, train_causal_nh_v2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from copy import copy

# %matplotlib inline

# %%
dataset_name = 'synth_2_events_small'

# %%
# path = f'../../data/NeuralHawkesData/data_bookorder/fold1/'
path = f'../../data/data_{dataset_name}/'

# %%
train = open_pkl_file(path + 'train.pkl', 'train')
dev = open_pkl_file(path + 'dev.pkl', 'dev')
test_data = open_pkl_file(path + 'test.pkl', 'test')

with open(path + 'A.pkl', 'rb') as f:
    A = pickle.load(f)
    
W = copy(A['A'])
A = A['A']
A[A>0] = 1

# %%
train_nh(train, dev, '../../artefacts/', False, lr=0.01, num_epochs=50, batch_size=10)
# Out:
# Processing data...
# start training...
# CUDA is not Available. You are using CPU only.
# Number of cores:  8
# Model is saved under 2021_12_13_41_45
# The log-likelihood at epoch 0: -1.2835130769062817
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 1: -1.2613181385567518
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 2: -1.254936329911395
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 3: -1.244926080471132
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 4: -1.2391841857413934
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 5: -1.2370484514934261
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 6: -1.2371958290658347
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 7: -1.2306663203045605
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 8: -1.2294994447289445
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 9: -1.23503759120538
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 10: -1.224175343087049
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 11: -1.2290899013116108
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 12: -1.2184512006558055
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 13: -1.213750935376175
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 14: -1.2086209428988821
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 15: -1.2100007840288365
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 16: -1.2014873473624872
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 17: -1.192333215232787
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 18: -1.190729156742251
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 19: -1.179750408389704
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 20: -1.1763552161736217
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 21: -1.1767915679187309
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 22: -1.1631668959206682
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 23: -1.1591939538474973
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 24: -1.1517419334349595
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 25: -1.1392874865027947
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 26: -1.1378375789983486
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 27: -1.1178372638981517
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 28: -1.1227509041142658
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 29: -1.1187179937595275
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 30: -1.1158729863360646
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 31: -1.1019624539507114
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 32: -1.0844520382764862
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 33: -1.0811015431473894
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 34: -1.0844068449687183
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 35: -1.0701272731874047
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 36: -1.072222391764323
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 37: -1.0402563575806656
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 38: -1.0255220986963287
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 39: -1.0099156077315168
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 40: -1.0183805946412126
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 41: -1.0103940389989838
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 42: -1.015242748725705
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 43: -0.9977911290114488
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 44: -0.9808215505708524
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 45: -0.9772773060372205
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 46: -0.9659859758082444
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 47: -0.9424928866750826
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
# The log-likelihood at epoch 48: -0.968861593851229
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
#
#
# The log-likelihood at epoch 49: -0.9529304628449727
#
# validating on log likelihood...
#
# validating on type prediction accuracy if we know when next event will happen...
# Saving training loss and validation data...
# If you have a trained model before this, please combine the previous train_date file to generate plots that are able to show the whole training information

# %%
path_to_init = '../../artefacts/2021_12_13_41_45'

# %%
original_time, original_type, estimated_times, estimated_types, estimated_intensities = test_prediction(
                test_data = test_data,
                idx_test_series=5,
                n_samples=1000,
                start_test_idx=10,
                path_to_initialization=path_to_init,
                dataset_name=dataset_name)
# Out:
# prediction at event 10 on a sequence of length 31 is done
# prediction at event 11 on a sequence of length 31 is done
# prediction at event 12 on a sequence of length 31 is done
# prediction at event 13 on a sequence of length 31 is done
# prediction at event 14 on a sequence of length 31 is done
# prediction at event 15 on a sequence of length 31 is done
# prediction at event 16 on a sequence of length 31 is done
# prediction at event 17 on a sequence of length 31 is done
# prediction at event 18 on a sequence of length 31 is done
# prediction at event 19 on a sequence of length 31 is done
# prediction at event 20 on a sequence of length 31 is done
# prediction at event 21 on a sequence of length 31 is done
# prediction at event 22 on a sequence of length 31 is done
# prediction at event 23 on a sequence of length 31 is done
# prediction at event 24 on a sequence of length 31 is done
# prediction at event 25 on a sequence of length 31 is done
# prediction at event 26 on a sequence of length 31 is done
# prediction at event 27 on a sequence of length 31 is done
# prediction at event 28 on a sequence of length 31 is done
# prediction at event 29 on a sequence of length 31 is done
# prediction at event 30 on a sequence of length 31 is done
